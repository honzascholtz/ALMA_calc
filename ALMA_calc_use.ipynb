# %%
import ALMA_obs_calc as Alm_calc
import numpy as np
#--------------

whatgals = []

whatgals.append({'NAME':'LRD',\
				 'SFR':31,\
			     'ZRED': 0.2227,\
			     'MSorSB':'MS',\
				 'Cosmo': None,
				 'alpha':7,\
				 'FWHM':92.,\
				 'numchan':3,\
				 'flipper':[False,False],\
				 'ZP':1.0,\
				 'PSF_n': 1,\
				 'mu': 1.,
				 'MH2': 1e8 , 
				 'CO_ladder': 'SF',\
                      })

for gal in whatgals:
	Target = Alm_calc.ALMA_calc(gal)
	#Target.CII_calc() # Estimates [CII158 micron info - - add LCII_Lsol=1e9 to directly take LCII rather than estimate it from SFR
	#Target.OIII_calc3() # Estimates [OIII]88 micron info - add LOIII_Lsol=1e9 to directly take LOIII rather than estimate it from SFR
	Target.CO_calc( [3]) # Estimates CO stuff - in this case for CO(3-2) - to add more add e.g. 4 for CO(4-3)
# Out:
# alpha 7
# MH2:  1.00E+8  Msol
# FWHM:  9.20E+1  km/s
# N12:1.43E+7
# ---
# L'CO(3-2):  1.00E+7  K km/s pc^2
# Sdv:  36.8  mJy km/s
# Rep Freq: 282.813  GHz
# Peak amplitude:  0.376  mJy
# Channel width:  30.7  km/s
# [0.273, 0.366, 0.273]  mJy
# SPW centres: [282.813, 284.688, 294.813, 296.688]
# ---
